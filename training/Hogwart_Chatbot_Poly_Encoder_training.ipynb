# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Dec  4 23:58:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install -q transformers datasets folium==0.2.1
# Out:
#      |████████████████████████████████| 5.8 MB 15.8 MB/s
#      |████████████████████████████████| 451 kB 70.0 MB/s
#      |████████████████████████████████| 69 kB 9.1 MB/s
#      |████████████████████████████████| 182 kB 75.2 MB/s
#      |████████████████████████████████| 7.6 MB 65.3 MB/s
#      |████████████████████████████████| 132 kB 63.1 MB/s
#      |████████████████████████████████| 212 kB 68.1 MB/s
#      |████████████████████████████████| 127 kB 70.5 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.17.5 requires folium>=0.9.1, but you have folium 0.2.1 which is incompatible.

# %%
# !git clone https://github.com/dotsnangles/Poly-Encoder.git
# Out:
# Cloning into 'Poly-Encoder'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 129 (delta 41), reused 20 (delta 8), pack-reused 57
# Receiving objects: 100% (129/129), 40.70 KiB | 13.57 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !gdown -q --folder 1snDkM3lV3Fx5YmoIESwxXSPGoXxy1vSP

# %%
# %cd /content/drive/MyDrive/메인프로젝트(5조)/chat_bot/train/Poly-Encoder
# Out:
# /content/drive/MyDrive/메인프로젝트(5조)/chat_bot/train/Poly-Encoder

# %% [markdown]
# 미리 생성해둔 run_new.py를 실행

# %%
# !python3 run_hogwart.py --bert_model 'klue/bert-base' --output_dir 'chatbot_output/' --train_dir 'data/' --train_file 'train_data_source_hogwart_QA.pickle' --dev_file 'val_data_source_hogwart_QA.pickle' --use_pretrain --architecture poly --poly_m 16 --num_train_epochs 100 --train_batch_size 4 --eval_batch_size 4 --gradient_accumulation_steps 1 --print_freq 200 --max_contexts_length 256 --max_response_length 128
# Out:
# Namespace(adam_epsilon=1e-08, architecture='poly', bert_model='klue/bert-base', dev_file='val_data_source_hogwart_QA.pickle', eval=False, eval_batch_size=4, fp16=False, fp16_opt_level='O1', gpu=0, gradient_accumulation_steps=1, learning_rate=5e-05, max_contexts_length=256, max_grad_norm=1.0, max_response_length=128, model_type='bert', num_train_epochs=100.0, output_dir='chatbot_output/', poly_m=16, print_freq=200, seed=12345, test_file='data/ubuntu_data', train_batch_size=4, train_dir='data/', train_file='train_data_source_hogwart_QA.pickle', use_pretrain=True, warmup_steps=100, weight_decay=0.01)
# Downloading: 100% 248k/248k [00:00<00:00, 2.30MB/s]
# Downloading: 100% 125/125 [00:00<00:00, 92.7kB/s]
# Downloading: 100% 289/289 [00:00<00:00, 205kB/s]
# Downloading: 100% 425/425 [00:00<00:00, 279kB/s]
# ...
# Train dir: data/
# Output dir: chatbot_output/
# ...
# Loading parameters from ./chatbot_output/poly_16_pytorch_model_17.bin
# Downloading: 100% 445M/445M [00:09<00:00, 46.8MB/s]
# ...
